# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.2

# %% [markdown]
# # 0 - Imports

# %%
# Fundamental libraries
import os
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Main model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, log_loss
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import ParameterGrid
from collections import defaultdict

# Models extension
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# Uncertainty analysis
from sklearn.utils import resample

from sklearn.metrics import confusion_matrix

# %% [markdown]
# # 1 - Data collection

# %% [markdown]
# ## 1.1 - Extract and download data to folder

# %%
urls = [
    'http://tennis-data.co.uk/2000/2000.xls', 
    #'http://tennis-data.co.uk/2001/2001.xls', 
    'http://tennis-data.co.uk/2002/2002.xls',
    'http://tennis-data.co.uk/2003/2003.xls', 
    'http://tennis-data.co.uk/2004/2004.xls',
    'http://tennis-data.co.uk/2005/2005.xls', 
    'http://tennis-data.co.uk/2006/2006.xls',
    'http://tennis-data.co.uk/2007/2007.xls', 
    #'http://tennis-data.co.uk/2008/2008.zip', 
    'http://tennis-data.co.uk/2009/2009.xls', 
    'http://tennis-data.co.uk/2010/2010.xls',
    'http://tennis-data.co.uk/2011/2011.xls', 
    'http://tennis-data.co.uk/2012/2012.xls',
    'http://tennis-data.co.uk/2013/2013.xlsx', 
    'http://tennis-data.co.uk/2014/2014.xlsx',
    'http://tennis-data.co.uk/2015/2015.xlsx', 
    'http://tennis-data.co.uk/2016/2016.xlsx', 
    'http://tennis-data.co.uk/2017/2017.xlsx', 
    'http://tennis-data.co.uk/2018/2018.xlsx',
    'http://tennis-data.co.uk/2019/2019.xlsx', 
    'http://tennis-data.co.uk/2020/2020.xlsx',
    'http://tennis-data.co.uk/2021/2021.xlsx', 
    'http://tennis-data.co.uk/2022/2022.xlsx',
    'http://tennis-data.co.uk/2023/2023.xlsx',
    'http://tennis-data.co.uk/2024/2024.xlsx',
    'http://tennis-data.co.uk/2025/2025.xlsx',
    'http://tennis-data.co.uk/2026/2026.xlsx'
]

# Folder to save files
save_folder = "datasets"
os.makedirs(save_folder, exist_ok=True)

for url in urls:
    filename = url.split("/")[-1]
    filepath = os.path.join(save_folder, filename)
    
    print(f"Downloading {filename}...")
    
    response = requests.get(url)
    with open(filepath, "wb") as f:
        f.write(response.content)
# Out:
# Downloading 2000.xls...
# Downloading 2002.xls...
# Downloading 2003.xls...
# Downloading 2004.xls...
# Downloading 2005.xls...
# Downloading 2006.xls...
# Downloading 2007.xls...
# Downloading 2009.xls...
# Downloading 2010.xls...
# Downloading 2011.xls...
# Downloading 2012.xls...
# Downloading 2013.xlsx...
# Downloading 2014.xlsx...
# Downloading 2015.xlsx...
# Downloading 2016.xlsx...
# Downloading 2017.xlsx...
# Downloading 2018.xlsx...
# Downloading 2019.xlsx...
# Downloading 2020.xlsx...
# Downloading 2021.xlsx...
# Downloading 2022.xlsx...
# Downloading 2023.xlsx...
# Downloading 2024.xlsx...
# Downloading 2025.xlsx...
# Downloading 2026.xlsx...

# %% [markdown]
# ## 1.2 - Read data and insert to dataframe

# %%
folder_path = "datasets"

# Dictionary to save dataframes
dfs = {}

for file in os.listdir(folder_path):
    filepath = os.path.join(folder_path, file)
    if file.endswith(".xlsx"):
        df = pd.read_excel(filepath)
        
    elif file.endswith(".xls"):
        df = pd.read_excel(filepath, engine="xlrd")
        
    else:
        continue
    
    # Use filename as key
    key = os.path.splitext(file)[0]
    dfs[key] = df
    
    print(f"Loaded {file} → key: '{key}', shape: {df.shape}")

print("\nTotal datasets loaded:", len(dfs))
# Out:
# Loaded 2000.xls → key: '2000', shape: (2963, 26)
# Loaded 2001.xls → key: '2001', shape: (2963, 34)
# Loaded 2002.xls → key: '2002', shape: (2854, 36)
# Loaded 2003.xls → key: '2003', shape: (2861, 36)
# Loaded 2004.xls → key: '2004', shape: (2877, 36)
# Loaded 2005.xls → key: '2005', shape: (2909, 38)
# Loaded 2006.xls → key: '2006', shape: (2909, 38)
# Loaded 2007.xls → key: '2007', shape: (2806, 38)
# Loaded 2008.xls → key: '2008', shape: (2707, 38)
# Loaded 2009.xls → key: '2009', shape: (2731, 38)
# Loaded 2010.xls → key: '2010', shape: (2679, 42)
# Loaded 2011.xls → key: '2011', shape: (2675, 42)
# Loaded 2012.xls → key: '2012', shape: (2607, 42)
# C:\Users\brand\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# Loaded 2013.xlsx → key: '2013', shape: (2631, 42)
# C:\Users\brand\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# Loaded 2014.xlsx → key: '2014', shape: (2600, 42)
# C:\Users\brand\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# Loaded 2015.xlsx → key: '2015', shape: (2630, 40)
# C:\Users\brand\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# Loaded 2016.xlsx → key: '2016', shape: (2626, 40)
# Loaded 2017.xlsx → key: '2017', shape: (2633, 40)
# Loaded 2018.xlsx → key: '2018', shape: (2637, 40)
# Loaded 2019.xlsx → key: '2019', shape: (2610, 36)
# Loaded 2020.xlsx → key: '2020', shape: (1267, 36)
# Loaded 2021.xlsx → key: '2021', shape: (2489, 36)
# Loaded 2022.xlsx → key: '2022', shape: (2632, 36)
# Loaded 2023.xlsx → key: '2023', shape: (2703, 36)
# Loaded 2024.xlsx → key: '2024', shape: (2703, 36)
# Loaded 2025.xlsx → key: '2025', shape: (2644, 38)
# Loaded 2026.xlsx → key: '2026', shape: (859, 38)
#
# Total datasets loaded: 27

# %% [markdown]
# ## 1.3 - Data cleaning and inspection

# %%
# Get sets of column names for each year/df
column_sets = [set(df.columns) for df in dfs.values()]

# Find columns present in all dfs
common_columns = set.intersection(*column_sets)

print(f"Columns present in all datasets ({len(common_columns)}):")
print(common_columns)
# Out:
# Columns present in all datasets (26):
# {'ATP', 'Lsets', 'Date', 'W2', 'W3', 'L4', 'Series', 'L5', 'Loser', 'Tournament', 'Best of', 'L3', 'Wsets', 'LRank', 'W1', 'W4', 'WRank', 'Surface', 'Location', 'Court', 'W5', 'Round', 'L2', 'Winner', 'L1', 'Comment'}

# %%
for year, df in dfs.items():
    unique_cols = set(df.columns) - common_columns
    if unique_cols:
        print(f"Columns only in {year}: {unique_cols}")
# Out:
# Columns only in 2001: {'GBW', 'CBW', 'GBL', 'CBL', 'SBL', 'SBW', 'IWL', 'IWW'}
# Columns only in 2002: {'GBW', 'CBW', 'GBL', 'CBL', 'B365W', 'SBL', 'SBW', 'IWL', 'IWW', 'B365L'}
# Columns only in 2003: {'CBW', 'CBL', 'B365W', 'SBL', 'B&WW', 'SBW', 'IWL', 'IWW', 'B365L', 'B&WL'}
# Columns only in 2004: {'EXL', 'PSL', 'CBW', 'CBL', 'B365W', 'EXW', 'PSW', 'IWL', 'IWW', 'B365L'}
# Columns only in 2005: {'EXL', 'PSL', 'CBW', 'CBL', 'B365W', 'EXW', 'PSW', 'WPts', 'IWL', 'IWW', 'B365L', 'LPts'}
# Columns only in 2006: {'EXL', 'PSL', 'CBW', 'CBL', 'B365W', 'EXW', 'UBL', 'PSW', 'WPts', 'B365L', 'LPts', 'UBW'}
# Columns only in 2007: {'EXL', 'PSL', 'CBW', 'CBL', 'B365W', 'EXW', 'UBL', 'PSW', 'WPts', 'B365L', 'LPts', 'UBW'}
# Columns only in 2008: {'EXL', 'PSL', 'B365W', 'UBL', 'EXW', 'LBW', 'PSW', 'WPts', 'LBL', 'B365L', 'LPts', 'UBW'}
# Columns only in 2009: {'EXL', 'SJL', 'B365W', 'UBL', 'EXW', 'LBW', 'SJW', 'WPts', 'LBL', 'B365L', 'LPts', 'UBW'}
# Columns only in 2010: {'EXL', 'SJL', 'AvgL', 'PSL', 'B365W', 'MaxL', 'EXW', 'LBW', 'SJW', 'MaxW', 'WPts', 'B365L', 'PSW', 'LBL', 'AvgW', 'LPts'}
# Columns only in 2011: {'EXL', 'SJL', 'AvgL', 'PSL', 'B365W', 'MaxL', 'EXW', 'LBW', 'SJW', 'MaxW', 'WPts', 'B365L', 'PSW', 'LBL', 'AvgW', 'LPts'}
# Columns only in 2012: {'EXL', 'SJL', 'AvgL', 'PSL', 'B365W', 'MaxL', 'EXW', 'LBW', 'SJW', 'MaxW', 'WPts', 'B365L', 'PSW', 'LBL', 'AvgW', 'LPts'}
# Columns only in 2013: {'EXL', 'SJL', 'AvgL', 'PSL', 'B365W', 'MaxL', 'EXW', 'LBW', 'SJW', 'MaxW', 'WPts', 'B365L', 'PSW', 'LBL', 'AvgW', 'LPts'}
# Columns only in 2014: {'EXL', 'SJL', 'AvgL', 'PSL', 'B365W', 'MaxL', 'EXW', 'LBW', 'SJW', 'MaxW', 'WPts', 'B365L', 'PSW', 'LBL', 'AvgW', 'LPts'}
# Columns only in 2015: {'EXL', 'AvgL', 'PSL', 'B365W', 'MaxL', 'EXW', 'LBW', 'PSW', 'MaxW', 'WPts', 'B365L', 'LBL', 'AvgW', 'LPts'}
# Columns only in 2016: {'EXL', 'AvgL', 'PSL', 'B365W', 'MaxL', 'EXW', 'LBW', 'PSW', 'MaxW', 'WPts', 'B365L', 'LBL', 'AvgW', 'LPts'}
# Columns only in 2017: {'EXL', 'AvgL', 'PSL', 'B365W', 'MaxL', 'EXW', 'LBW', 'PSW', 'MaxW', 'WPts', 'B365L', 'LBL', 'AvgW', 'LPts'}
# Columns only in 2018: {'EXL', 'AvgL', 'PSL', 'B365W', 'MaxL', 'EXW', 'LBW', 'PSW', 'MaxW', 'WPts', 'B365L', 'LBL', 'AvgW', 'LPts'}
# Columns only in 2019: {'LPts', 'AvgL', 'PSL', 'B365W', 'MaxL', 'PSW', 'B365L', 'WPts', 'AvgW', 'MaxW'}
# Columns only in 2020: {'LPts', 'AvgL', 'PSL', 'B365W', 'MaxL', 'PSW', 'B365L', 'WPts', 'AvgW', 'MaxW'}
# Columns only in 2021: {'LPts', 'AvgL', 'PSL', 'B365W', 'MaxL', 'PSW', 'B365L', 'WPts', 'AvgW', 'MaxW'}
# Columns only in 2022: {'LPts', 'AvgL', 'PSL', 'B365W', 'MaxL', 'PSW', 'B365L', 'WPts', 'AvgW', 'MaxW'}
# Columns only in 2023: {'LPts', 'AvgL', 'PSL', 'B365W', 'MaxL', 'PSW', 'B365L', 'WPts', 'AvgW', 'MaxW'}
# Columns only in 2024: {'LPts', 'AvgL', 'PSL', 'B365W', 'MaxL', 'PSW', 'B365L', 'WPts', 'AvgW', 'MaxW'}
# Columns only in 2025: {'AvgL', 'PSL', 'B365W', 'MaxL', 'BFEW', 'BFEL', 'PSW', 'MaxW', 'WPts', 'B365L', 'AvgW', 'LPts'}
# Columns only in 2026: {'AvgL', 'PSL', 'B365W', 'MaxL', 'BFEW', 'BFEL', 'PSW', 'MaxW', 'WPts', 'B365L', 'AvgW', 'LPts'}

# %% [markdown]
# ### 1.3.1 - Drop 2000-2004, 2026 dataframes

# %%
years_to_drop = ['2000','2001', '2002', '2003', '2004', '2026']

for year in years_to_drop:
    if year in dfs:
        del dfs[year]
    else:
        print(f"{year} not found in dfs")

# %% [markdown]
# ### 1.3.2 - Drop bookmaker columns and keep used columns

# %%
# List of columns to keep
columns_to_keep = ['WPts', 'LPts', 'L5', 'Location', 'Winner', 'Date', 'ATP', 'Comment', 'W2', 'W5', 'L1', 'L3', 'Lsets', 'W4', 'Loser', 'Wsets', 'W1', 'LRank', 'WRank', 'Round', 'Surface', 'Best of', 'L2', 'W3', 'Tournament', 'Series', 'L4', 'Court']  

# Drop bookmaker columns across all DataFrames
for key, df in dfs.items():
    # Keep only the columns that exist in both the DataFrame and kept-columns list
    keep_cols = [col for col in df.columns if col in columns_to_keep]
    dfs[key] = df[keep_cols].copy()  # assign back a clean copy
    print(f"{key}: kept columns {dfs[key].columns.tolist()}")
# Out:
# 2005: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2006: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2007: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2008: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2009: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2010: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2011: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2012: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2013: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2014: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2015: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2016: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2017: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2018: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2019: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2020: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2021: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2022: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2023: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2024: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']
# 2025: kept columns ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']

# %% [markdown]
# ### 1.3.3 - Rows and columns inspection

# %%
total_rows = 0
for year, df in dfs.items():
    print(f"\n--- {year} ---")
    # number of rows
    n_rows = int(df.shape[0])
    total_rows += n_rows
    # number of columns
    n_cols = df.shape[1]
    print(f"Rows: {n_rows}, Columns: {n_cols}")
print("Total rows:",total_rows)
# Out:
# --- 2005 ---
# Rows: 2909, Columns: 28
#
# --- 2006 ---
# Rows: 2909, Columns: 28
#
# --- 2007 ---
# Rows: 2806, Columns: 28
#
# --- 2008 ---
# Rows: 2707, Columns: 28
#
# --- 2009 ---
# Rows: 2731, Columns: 28
#
# --- 2010 ---
# Rows: 2679, Columns: 28
#
# --- 2011 ---
# Rows: 2675, Columns: 28
#
# --- 2012 ---
# Rows: 2607, Columns: 28
#
# --- 2013 ---
# Rows: 2631, Columns: 28
#
# --- 2014 ---
# Rows: 2600, Columns: 28
#
# --- 2015 ---
# Rows: 2630, Columns: 28
#
# --- 2016 ---
# Rows: 2626, Columns: 28
#
# --- 2017 ---
# Rows: 2633, Columns: 28
#
# --- 2018 ---
# Rows: 2637, Columns: 28
#
# --- 2019 ---
# Rows: 2610, Columns: 28
#
# --- 2020 ---
# Rows: 1267, Columns: 28
#
# --- 2021 ---
# Rows: 2489, Columns: 28
#
# --- 2022 ---
# Rows: 2632, Columns: 28
#
# --- 2023 ---
# Rows: 2703, Columns: 28
#
# --- 2024 ---
# Rows: 2703, Columns: 28
#
# --- 2025 ---
# Rows: 2644, Columns: 28
# Total rows: 54828

# %% [markdown]
# ### 1.3.4 - Value checking

# %%
for year, df in dfs.items():
    print(f"\n--- {year} ---")
    
    # Total number of rows
    n_rows = df.shape[0]
    n_cols = df.shape[1]
    print(f"Rows: {n_rows}, Columns: {n_cols}")
    
    # Check missing / null values per column
    missing = df.isnull().sum()
    print("Missing values per column:")
    print(missing)
# Out:
# --- 2005 ---
# Rows: 2909, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            0
# LRank            7
# WPts          1676
# LPts          1679
# W1              11
# L1              11
# W2              29
# L2              29
# W3            1572
# L3            1572
# W4            2660
# L4            2660
# W5            2813
# L5            2813
# Wsets            9
# Lsets            9
# Comment          0
# dtype: int64
#
# --- 2006 ---
# Rows: 2909, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            2
# LRank            7
# WPts             2
# LPts             8
# W1              12
# L1              12
# W2              43
# L2              42
# W3            1510
# L3            1510
# W4            2660
# L4            2660
# W5            2808
# L5            2808
# Wsets           12
# Lsets           12
# Comment          0
# dtype: int64
#
# --- 2007 ---
# Rows: 2806, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            1
# LRank            5
# WPts             1
# LPts             5
# W1              10
# L1              10
# W2              40
# L2              40
# W3            1574
# L3            1574
# W4            2581
# L4            2581
# W5            2720
# L5            2720
# Wsets            7
# Lsets            6
# Comment          0
# dtype: int64
#
# --- 2008 ---
# Rows: 2707, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            1
# LRank            9
# WPts             1
# LPts             9
# W1              19
# L1              19
# W2              46
# L2              46
# W3            1493
# L3            1493
# W4            2463
# L4            2463
# W5            2621
# L5            2621
# Wsets           19
# Lsets           19
# Comment          0
# dtype: int64
#
# --- 2009 ---
# Rows: 2731, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            0
# LRank            6
# WPts             0
# LPts             6
# W1              16
# L1              16
# W2              47
# L2              47
# W3            1466
# L3            1466
# W4            2495
# L4            2495
# W5            2639
# L5            2639
# Wsets           15
# Lsets           15
# Comment          0
# dtype: int64
#
# --- 2010 ---
# Rows: 2679, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            1
# LRank            5
# WPts             1
# LPts             5
# W1              16
# L1              16
# W2              46
# L2              46
# W3            1479
# L3            1479
# W4            2435
# L4            2435
# W5            2578
# L5            2578
# Wsets           16
# Lsets           16
# Comment          0
# dtype: int64
#
# --- 2011 ---
# Rows: 2675, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            0
# LRank            1
# WPts             0
# LPts             1
# W1              14
# L1              14
# W2              45
# L2              45
# W3            1456
# L3            1456
# W4            2453
# L4            2453
# W5            2602
# L5            2602
# Wsets           14
# Lsets           14
# Comment          0
# dtype: int64
#
# --- 2012 ---
# Rows: 2607, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            1
# LRank            6
# WPts             0
# LPts             5
# W1              16
# L1              16
# W2              44
# L2              44
# W3            1440
# L3            1440
# W4            2348
# L4            2348
# W5            2501
# L5            2501
# Wsets           16
# Lsets           16
# Comment          0
# dtype: int64
#
# --- 2013 ---
# Rows: 2631, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            1
# LRank            6
# WPts             1
# LPts             6
# W1              18
# L1              18
# W2              47
# L2              47
# W3            1386
# L3            1386
# W4            2405
# L4            2405
# W5            2534
# L5            2534
# Wsets           17
# Lsets           17
# Comment          0
# dtype: int64
#
# --- 2014 ---
# Rows: 2600, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            0
# LRank            2
# WPts             0
# LPts             2
# W1              25
# L1              25
# W2              52
# L2              52
# W3            1378
# L3            1378
# W4            2373
# L4            2373
# W5            2518
# L5            2518
# Wsets           25
# Lsets           25
# Comment          0
# dtype: int64
#
# --- 2015 ---
# Rows: 2630, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            3
# LRank            6
# WPts             3
# LPts             6
# W1               9
# L1               9
# W2              36
# L2              36
# W3            1353
# L3            1353
# W4            2383
# L4            2383
# W5            2534
# L5            2534
# Wsets            9
# Lsets            9
# Comment          0
# dtype: int64
#
# --- 2016 ---
# Rows: 2626, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            1
# LRank            7
# WPts             1
# LPts             7
# W1              18
# L1              18
# W2              40
# L2              40
# W3            1398
# L3            1398
# W4            2377
# L4            2377
# W5            2534
# L5            2534
# Wsets           20
# Lsets           20
# Comment          0
# dtype: int64
#
# --- 2017 ---
# Rows: 2633, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            0
# LRank            6
# WPts             0
# LPts             6
# W1              15
# L1              14
# W2              46
# L2              46
# W3            1358
# L3            1358
# W4            2393
# L4            2393
# W5            2550
# L5            2550
# Wsets           16
# Lsets           17
# Comment          0
# dtype: int64
#
# --- 2018 ---
# Rows: 2637, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            0
# LRank            1
# WPts             0
# LPts             1
# W1              15
# L1              14
# W2              30
# L2              30
# W3            1341
# L3            1341
# W4            2372
# L4            2372
# W5            2546
# L5            2546
# Wsets           14
# Lsets           15
# Comment          0
# dtype: int64
#
# --- 2019 ---
# Rows: 2610, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            4
# LRank           13
# WPts             3
# LPts            13
# W1              21
# L1              21
# W2              34
# L2              34
# W3            1362
# L3            1362
# W4            2345
# L4            2345
# W5            2514
# L5            2514
# Wsets           21
# Lsets           21
# Comment          0
# dtype: int64
#
# --- 2020 ---
# Rows: 1267, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            1
# LRank            5
# WPts             1
# LPts             5
# W1               6
# L1               6
# W2              14
# L2              14
# W3             564
# L3             564
# W4            1088
# L4            1088
# W5            1192
# L5            1192
# Wsets            6
# Lsets            6
# Comment          0
# dtype: int64
#
# --- 2021 ---
# Rows: 2489, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            0
# LRank            6
# WPts             0
# LPts             6
# W1              21
# L1              20
# W2              40
# L2              40
# W3            1295
# L3            1295
# W4            2217
# L4            2217
# W5            2389
# L5            2389
# Wsets           20
# Lsets           21
# Comment          0
# dtype: int64
#
# --- 2022 ---
# Rows: 2632, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of         15
# Winner           0
# Loser            0
# WRank            0
# LRank            2
# WPts             0
# LPts             2
# W1              17
# L1              17
# W2              32
# L2              32
# W3            1368
# L3            1368
# W4            2364
# L4            2364
# W5            2533
# L5            2533
# Wsets           17
# Lsets           17
# Comment          0
# dtype: int64
#
# --- 2023 ---
# Rows: 2703, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            2
# LRank            7
# WPts             2
# LPts             7
# W1              19
# L1              19
# W2              43
# L2              43
# W3            1415
# L3            1415
# W4            2431
# L4            2431
# W5            2603
# L5            2603
# Wsets           19
# Lsets           19
# Comment          0
# dtype: int64
#
# --- 2024 ---
# Rows: 2703, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            0
# LRank            2
# WPts             0
# LPts             2
# W1              19
# L1              19
# W2              33
# L2              33
# W3            1436
# L3            1436
# W4            2410
# L4            2410
# W5            2584
# L5            2584
# Wsets           18
# Lsets           18
# Comment          0
# dtype: int64
#
# --- 2025 ---
# Rows: 2644, Columns: 28
# Missing values per column:
# ATP              0
# Location         0
# Tournament       0
# Date             0
# Series           0
# Court            0
# Surface          0
# Round            0
# Best of          0
# Winner           0
# Loser            0
# WRank            0
# LRank            3
# WPts             0
# LPts             3
# W1              22
# L1              22
# W2              45
# L2              46
# W3            1383
# L3            1383
# W4            2376
# L4            2376
# W5            2544
# L5            2544
# Wsets           22
# Lsets           22
# Comment          0
# dtype: int64

# %% [markdown]
# ### 1.3.5 - Identify categorical and numerical columns, and unique categorical values

# %%
for year, df in dfs.items():
    print(f"\n--- {year} ---")
    
    # Separate column types
    numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
    categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
    
    print(f"Numerical columns: {numerical_cols}")
    # for col in numerical_cols:
    #     unique_vals = df[col].unique()
    #     print(f"  {col}: {len(unique_vals)} unique values -> {unique_vals[:10]}{'...' if len(unique_vals) > 10 else ''}")
    
    print(f"\nCategorical columns: {categorical_cols}")
    for col in categorical_cols:
        unique_vals = df[col].unique()
        print(f"  {col}: {len(unique_vals)} unique values -> {unique_vals[:10]}{'...' if len(unique_vals) > 10 else ''}")
# Out:
# --- 2005 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'W2', 'L2', 'W3', 'L3', 'Comment']
#   Location: 66 unique values -> ['Adelaide' 'Chennai' 'Doha' 'Auckland' 'Sydney' 'Melbourne'
#  'Delray Beach' 'Milan' 'Vina del Mar' 'Buenos Aires']...
#   Tournament: 67 unique values -> ['Next Generation Hardcourts' 'TATA Open' 'Qatar Exxon Mobil Open'
#  'Heineken Open' 'Medibank International' 'Australian Open'
#  'International Championships' 'Internazionali di Lombardia'
#  'Bellsouth Open' 'ATP Buenos Aires 2005']...
#   Series: 5 unique values -> ['International' 'Grand Slam' 'International Gold' 'Masters' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 4 unique values -> ['Hard' 'Carpet' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 225 unique values -> ['Saulnier C.' 'Enqvist T.' 'Melzer J.' 'Rochus O.' 'Mayer F.' 'Kiefer N.'
#  'Malisse X.' 'Benneteau J.' 'Stepanek R.' 'Dent T.']...
#   Loser: 337 unique values -> ['Baccanello P.' 'Sluiter R.' 'Berdych T.' 'Dupuis A.' 'Arthurs W.'
#  'Schalken S.' 'Martin A.' 'Starace P.' 'Kohlschreiber P.' 'Ginepri R.']...
#   W2: 10 unique values -> [7 6 4 3 2 5 nan 0 1 ' ']
#   L2: 10 unique values -> [6 1 4 5 3 7 2 0 nan ' ']
#   W3: 10 unique values -> [nan 7 6 1 3 4 2 5 0 ' ']
#   L3: 10 unique values -> [nan 6 1 5 2 4 3 0 7 ' ']
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']
#
# --- 2006 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'W2', 'L2', 'W3', 'L3', 'Comment']
#   Location: 66 unique values -> ['Adelaide' 'Chennai' 'Doha' 'Auckland' 'Sydney' 'Melbourne'
#  'Delray Beach' 'Vina del Mar' 'Zagreb' 'Buenos Aires']...
#   Tournament: 67 unique values -> ['Next Generation Adelaide International' 'Chennai Open'
#  'Qatar Exxon Mobil Open' 'Heineken Open' 'Sydney International'
#  'Australian Open' 'International Championships' 'Movistar Open'
#  'PBZ Zagreb Indoors' 'Copa Telmex']...
#   Series: 5 unique values -> ['International' 'Grand Slam' 'International Gold' 'Masters' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 4 unique values -> ['Hard' 'Clay' 'Carpet' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 246 unique values -> ['Berdych T.' 'Kohlschreiber P.' 'Malisse X.' 'Robredo T.' 'Ancic M.'
#  'Mayer F.' 'Seppi A.' 'Philippoussis M.' 'Karlovic I.' 'Blake J.']...
#   Loser: 367 unique values -> ['Calleri A.' 'Guccione C.' 'Luczak P.' 'Melzer J.' 'Clement A.'
#  'Monaco J.' 'Pashanski B.' 'Spadea V.' 'Chela J.I.' 'Martin A.']...
#   W2: 10 unique values -> [6 3 7 4 0 2 1 nan 5 ' ']
#   L2: 10 unique values -> [7 3 4 2 6 1 0 5 nan ' ']
#   W3: 10 unique values -> [6 nan 7 1 4 3 5 2 ' ' 0]
#   L3: 10 unique values -> [4 nan 1 2 3 6 5 0 7 ' ']
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']
#
# --- 2007 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 65 unique values -> ['Adelaide' 'Chennai' 'Doha' 'Auckland' 'Sydney' 'Melbourne'
#  'Delray Beach' 'Vina del Mar' 'Zagreb' 'Costa Do Sauipe']...
#   Tournament: 66 unique values -> ['Next Generation Adelaide International' 'Chennai Open'
#  'Qatar Exxon Mobil Open' 'Heineken Open' 'Sydney International'
#  'Australian Open' 'International Championships' 'Movistar Open'
#  'PBZ Zagreb Indoors' 'Brasil Open']...
#   Series: 5 unique values -> ['International' 'Grand Slam' 'International Gold' 'Masters' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 4 unique values -> ['Hard' 'Clay' 'Carpet' 'Grass']
#   Round: 8 unique values -> ['Round Robin' 'Quarterfinals' 'Semifinals' 'The Final' '1st Round'
#  '2nd Round' '3rd Round' '4th Round']
#   Winner: 227 unique values -> ['Luczak P.' 'Serra F.' 'Jones A.' 'Guccione C.' 'Mathieu P.H.'
#  'Djokovic N.' 'Goldstein P.' 'Gasquet R.' 'Spadea V.' 'Hewitt L.']...
#   Loser: 334 unique values -> ['Hrbaty D.' 'Johansson J.' 'Hajek J.' 'Becker B.' 'Hernych J.' 'Mayer F.'
#  'Stepanek R.' 'Tipsarevic J.' 'Luczak P.' 'Dancevic F.']...
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']
#
# --- 2008 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 64 unique values -> ['Adelaide' 'Chennai' 'Doha' 'Auckland' 'Sydney' 'Melbourne'
#  'Vina del Mar' 'Costa Do Sauipe' 'Delray Beach' 'Marseille']...
#   Tournament: 65 unique values -> ['Next Generation Adelaide International' 'Chennai Open'
#  'Qatar Exxon Mobil Open' 'Heineken Open' 'Medibank International'
#  'Australian Open' 'Movistar Open' 'Brasil Open'
#  'International Championships' 'Open 13']...
#   Series: 5 unique values -> ['International' 'Grand Slam' 'International Gold' 'Masters' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 4 unique values -> ['Hard' 'Clay' 'Carpet' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 226 unique values -> ['Querrey S.' 'Sirianni J.' 'Russell M.' 'Becker B.' 'Zverev M.'
#  'Llodra M.' 'Mathieu P.H.' 'Korolev E.' 'Guccione C.' 'Nieminen J.']...
#   Loser: 346 unique values -> ['Darcis S.' 'Stepanek R.' 'Del Potro J.M.' 'Smeets R.' 'Mayer F.'
#  'Simon G.' 'Benneteau J.' 'Jones A.' 'Odesnik W.' 'Klec I.']...
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']
#
# --- 2009 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 63 unique values -> ['Brisbane' 'Chennai' 'Doha' 'Auckland' 'Sydney' 'Melbourne'
#  'Johannesburg ' 'Vina del Mar' 'Zagreb' 'Costa Do Sauipe']...
#   Tournament: 65 unique values -> ['Brisbane International' 'Chennai Open' 'Qatar Exxon Mobil Open'
#  'Heineken Open' 'Medibank International' 'Australian Open'
#  'SA Tennis Open' 'Movistar Open' 'PBZ Zagreb Indoors' 'Brasil Open']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 4 unique values -> ['Hard' 'Clay' 'Carpet' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 234 unique values -> ['Gasquet R.' 'Dent T.' 'Benneteau J.' 'Soderling R.' 'Nieminen J.'
#  'Stepanek R.' 'Melzer J.' 'Verdasco F.' 'Berdych T.' 'Serra F.']...
#   Loser: 362 unique values -> ['Gicquel M.' 'Darcis S.' 'Ginepri R.' 'Querrey S.' 'Baghdatis M.'
#  'Kunitsyn I.' 'Fish M.' 'Tomic B.' 'Klein B.' 'Ferrero J.C.']...
#   Comment: 3 unique values -> ['Completed' 'Walkover' 'Retired']
#
# --- 2010 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 63 unique values -> ['Brisbane' 'Chennai' 'Doha' 'Auckland' 'Sydney' 'Melbourne'
#  'Johannesburg ' 'Santiago' 'Zagreb' 'Costa Do Sauipe']...
#   Tournament: 65 unique values -> ['Brisbane International' 'Chennai Open' 'Qatar Exxon Mobil Open'
#  'Heineken Open' 'Medibank International' 'Australian Open'
#  'SA Tennis Open' 'Movistar Open' 'PBZ Zagreb Indoors' 'Brasil Open']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 218 unique values -> ['Gasquet R.' 'Odesnik W.' 'Gicquel M.' 'Falla A.' 'Levy H.' 'Bellucci T.'
#  'Stepanek R.' 'Roddick A.' 'Dolgopolov O.' 'Berdych T.']...
#   Loser: 321 unique values -> ['Nieminen J.' 'Clement A.' 'Petzschner P.' 'Chardy J.' 'Llodra M.'
#  'Chela J.I.' 'Millman J.' 'Luczak P.' 'Tomic B.' 'Lindahl N.']...
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']
#
# --- 2011 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 63 unique values -> ['Brisbane' 'Chennai' 'Doha' 'Auckland' 'Sydney' 'Melbourne'
#  'Johannesburg ' 'Santiago' 'Zagreb' 'Costa Do Sauipe']...
#   Tournament: 65 unique values -> ['Brisbane International' 'Chennai Open' 'Qatar Exxon Mobil Open'
#  'Heineken Open' 'Medibank International' 'Australian Open'
#  'SA Tennis Open' 'Movistar Open' 'PBZ Zagreb Indoors' 'Brasil Open']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 207 unique values -> ['Lopez F.' 'Istomin D.' 'Berrer M.' 'Kubot L.' 'Mayer F.' 'Giraldo S.'
#  'Dolgopolov O.' 'Roddick A.' 'Stepanek R.' 'Becker B.']...
#   Loser: 310 unique values -> ['Petzschner P.' 'De Bakker T.' 'Sela D.' 'Brands D.' 'Tomic B.'
#  'Simon G.' 'Andreev I.' 'Matosevic M.' 'Kamke T.' 'Verdasco F.']...
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']
#
# --- 2012 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 63 unique values -> ['Brisbane' 'Chennai' 'Doha' 'Auckland' 'Sydney' 'Melbourne' 'Montpellier'
#  'Vina del Mar' 'Zagreb' 'Rotterdam']...
#   Tournament: 65 unique values -> ['Brisbane International' 'Chennai Open' 'Qatar Exxon Mobil Open'
#  'Heineken Open' 'Apia International' 'Australian Open'
#  'Open Sud de France' 'VTR Open' 'PBZ Zagreb Indoors'
#  'ABN AMRO World Tennis Tournament']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 207 unique values -> ['Duckworth J.' 'Dolgopolov O.' 'Istomin D.' 'Tomic B.' 'Muller G.'
#  'Simon G.' 'Baghdatis M.' 'Nishikori K.' 'Nieminen J.' 'Ito T.']...
#   Loser: 306 unique values -> ['Mahut N.' 'Falla A.' 'Mayer F.' 'Benneteau J.' 'Mello R.' 'Sweeting R.'
#  'Harrison R.' 'Stebe C.M.' 'Levine J.' 'Mitchell B.']...
#   Comment: 4 unique values -> ['Completed' 'Retired' 'Walkover' 'Disqualified']
#
# --- 2013 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 63 unique values -> ['Brisbane' 'Chennai' 'Doha' 'Auckland' 'Sydney' 'Melbourne' 'Montpellier'
#  'Vina del Mar' 'Zagreb' 'Rotterdam']...
#   Tournament: 65 unique values -> ['Brisbane International' 'Chennai Open' 'Qatar Exxon Mobil Open'
#  'Heineken Open' 'Apia International' 'Australian Open'
#  'Open Sud de France' 'VTR Open' 'PBZ Zagreb Indoors'
#  'ABN AMRO World Tennis Tournament']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 199 unique values -> ['Mayer F.' 'Nieminen J.' 'Nishikori K.' 'Baghdatis M.' 'Istomin D.'
#  'Millman J.' 'Falla A.' 'Melzer J.' 'Robredo T.' 'Dimitrov G.']...
#   Loser: 306 unique values -> ['Giraldo S.' 'Benneteau J.' 'Matosevic M.' 'Mitchell B.' 'Klizan M.'
#  'Ito T.' 'Levine J.' 'Kudla D.' 'Harrison R.' 'Baker B.']...
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']
#
# --- 2014 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 62 unique values -> ['Brisbane' 'Chennai' 'Doha' 'Auckland' 'Sydney' 'Melbourne' 'Montpellier'
#  'Vina del Mar' 'Zagreb' 'Buenos Aires']...
#   Tournament: 64 unique values -> ['Brisbane International' 'Chennai Open' 'Qatar Exxon Mobil Open'
#  'Heineken Open' 'Apia International' 'Australian Open'
#  'Open Sud de France' 'Royal Guard Open Chile' 'PBZ Zagreb Indoors'
#  'Copa Claro']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 197 unique values -> ['Matosevic M.' 'Nieminen J.' 'Cilic M.' 'Querrey S.' 'Dimitrov G.'
#  'Mahut N.' 'Ebden M.' 'Lopez F.' 'Chardy J.' 'Copil M.']...
#   Loser: 291 unique values -> ['Benneteau J.' 'Duckworth J.' 'Istomin D.' 'Tursunov D.' 'Haase R.'
#  'Sijsling I.' 'Kuznetsov Al.' 'Kukushkin M.' 'Mannarino A.' 'Sugita Y.']...
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']
#
# --- 2015 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 64 unique values -> ['Brisbane' 'Chennai' 'Doha' 'Auckland' 'Sydney' 'Melbourne' 'Montpellier'
#  'Quito' 'Zagreb' 'Memphis']...
#   Tournament: 66 unique values -> ['Brisbane International' 'Chennai Open' 'Qatar Exxon Mobil Open'
#  'Heineken Open' 'Apia International' 'Australian Open'
#  'Open Sud de France' 'Ecuador Open' 'PBZ Zagreb Indoors' 'Memphis Open']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 192 unique values -> ['Duckworth J.' 'Kokkinakis T.' 'Chardy J.' 'Tomic B.' 'Kukushkin M.'
#  'Kubot L.' 'Johnson S.' 'Nieminen J.' 'Klizan M.' 'Millman J.']...
#   Loser: 284 unique values -> ['Simon G.' 'Benneteau J.' 'Golubev A.' 'Querrey S.' 'Copil M.'
#  'Anderson K.' 'Matosevic M.' 'Kudla D.' 'Melzer J.' 'Williams R.']...
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']
#
# --- 2016 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 64 unique values -> ['Brisbane' 'Chennai' 'Doha' 'Auckland' 'Sydney' 'Melbourne' 'Montpellier'
#  'Quito' 'Sofia' 'Buenos Aires']...
#   Tournament: 66 unique values -> ['Brisbane International' 'Chennai Open' 'Qatar Exxon Mobil Open'
#  'ASB Classic' 'Apia International' 'Australian Open' 'Open Sud de France'
#  'Ecuador Open' 'Garanti Koza Sofia Open' 'Argentina Open']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 212 unique values -> ['Dimitrov G.' 'Kudla D.' 'Kamke T.' 'Chung H.' 'Goffin D.' 'Troicki V.'
#  'Thiem D.' 'Stepanek R.' 'Dodig I.' 'Pouille L.']...
#   Loser: 304 unique values -> ['Simon G.' 'Smith J.P.' 'Mitchell B.' 'Groth S.' 'Bellucci T.'
#  'Johnson S.' 'Duckworth J.' 'Lajovic D.' 'Anderson O.' 'Nishioka Y.']...
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']
#
# --- 2017 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 65 unique values -> ['Brisbane' 'Chennai' 'Doha' 'Auckland' 'Sydney' 'Melbourne' 'Montpellier'
#  'Quito' 'Sofia' 'Buenos Aires']...
#   Tournament: 67 unique values -> ['Brisbane International' 'Chennai Open' 'Qatar Exxon Mobil Open'
#  'ASB Classic' 'Apia International' 'Australian Open' 'Open Sud de France'
#  'Ecuador Open' 'Garanti Koza Sofia Open' 'Argentina Open']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 215 unique values -> ['Thompson J.' 'Mahut N.' 'Ferrer D.' 'Edmund K.' 'Dimitrov G.'
#  'Donaldson J.' 'Groth S.' 'Pouille L.' 'Troicki V.' 'Schwartzman D.']...
#   Loser: 307 unique values -> ['Ymer E.' 'Robert S.' 'Tomic B.' 'Escobedo E.' 'Johnson S.' 'Muller G.'
#  'Herbert P.H.' 'Simon G.' 'Nishioka Y.' 'Querrey S.']...
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']
#
# --- 2018 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 64 unique values -> ['Brisbane' 'Doha' 'Pune' 'Auckland' 'Sydney' 'Melbourne' 'Montpellier'
#  'Quito' 'Sofia' 'Buenos Aires']...
#   Tournament: 67 unique values -> ['Brisbane International' 'Qatar Exxon Mobil Open' 'Tata Open'
#  'ASB Classic' 'Sydney International' 'Australian Open'
#  'Open Sud de France' 'Ecuador Open' 'Garanti Koza Sofia Open'
#  'Argentina Open']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 211 unique values -> ['Dolgopolov O.' 'De Minaur A.' 'Harrison R.' 'Ebden M.' 'Zverev M.'
#  'Zeballos H.' 'Donaldson J.' 'Mmoh M.' 'Chung H.' 'Edmund K.']...
#   Loser: 291 unique values -> ['Schwartzman D.' 'Johnson S.' 'Mayer L.' 'Tiafoe F.' 'Smith J.P.'
#  'Escobedo E.' 'Thompson J.' 'Delbonis F.' 'Muller G.' 'Shapovalov D.']...
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']
#
# --- 2019 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 63 unique values -> ['Brisbane' 'Doha' 'Pune' 'Auckland' 'Sydney' 'Melbourne' 'Cordoba'
#  'Montpellier' 'Sofia' 'Buenos Aires']...
#   Tournament: 66 unique values -> ['Brisbane International' 'Qatar Exxon Mobil Open' 'Maharashtra Open'
#  'ASB Classic' 'Sydney International' 'Australian Open' 'Cordoba Open'
#  'Open Sud de France' 'Sofia Open' 'Argentina Open']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 204 unique values -> ['Dimitrov G.' 'Raonic M.' 'Kecmanovic M.' 'Millman J.' 'Uchiyama Y.'
#  'Kudla D.' 'Chardy J.' 'Murray A.' 'Kyrgios N.' 'Tsonga J.W.']...
#   Loser: 291 unique values -> ['Nishioka Y.' 'Bedene A.' 'Mayer L.' 'Sandgren T.' 'Humbert U.'
#  'Fritz T.' 'Struff J.L.' 'Duckworth J.' 'Harrison R.' 'Kokkinakis T.']...
#   Comment: 5 unique values -> ['Completed' 'Walkover' 'Retired' 'Awarded' 'Sched']
#
# --- 2020 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 28 unique values -> ['Doha' 'Auckland' 'Adelaide' 'Melbourne' 'Cordoba' 'Montpellier' 'Pune'
#  'Buenos Aires' 'New York' 'Rotterdam']...
#   Tournament: 32 unique values -> ['Qatar Exxon Mobil Open' 'ASB Classic' 'Adelaide International'
#  'Australian Open' 'Cordoba Open' 'Open Sud de France' 'Maharashtra Open'
#  'Argentina Open' 'New York Open' 'ABN AMRO World Tennis Tournament']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 2 unique values -> ['Hard' 'Clay']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 169 unique values -> ['Bublik A.' 'Moutet C.' 'Verdasco F.' 'Bedene A.' 'Chardy J.'
#  'Kecmanovic M.' 'Krajinovic F.' 'Djere L.' 'Fucsovics M.' 'Ilkel C.']...
#   Loser: 237 unique values -> ['Mannarino A.' 'Sandgren T.' 'Andujar P.' 'Ymer M.' 'Barrere G.'
#  'Thompson J.' 'Edmund K.' 'Sonego L.' 'Tiafoe F.' 'Berankis R.']...
#   Comment: 4 unique values -> ['Completed' 'Retired' 'Walkover' 'Disqualified']
#
# --- 2021 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 57 unique values -> ['Antalya' 'Delray Beach' 'Melbourne' 'Cordoba' 'Montpellier' 'Singapore'
#  'Buenos Aires' 'Rotterdam' 'Doha' 'Marseille']...
#   Tournament: 60 unique values -> ['Antalya Open' 'Delray Beach Open' 'Great Ocean Road Open'
#  'Murray River Open' 'Australian Open' 'Cordoba Open' 'Open Sud de France'
#  'Singapore Open' 'Argentina Open' 'ABN AMRO World Tennis Tournament']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Indoor' 'Outdoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 215 unique values -> ['Basilashvili N.' 'Celikbilek A.' 'Ruusuvuori E.' 'Bublik A.' 'Goffin D.'
#  'Travaglia S.' 'Struff J.L.' 'Lamasine T.' 'Andreev A.' 'Grenier H.']...
#   Loser: 307 unique values -> ['Arnaboldi A.' 'Zuk K.' 'Vesely J.' 'Caruso S.' 'Herbert P.H.'
#  'Kecmanovic M.' 'Kotov P.' 'Gerasimov E.' 'Ilhan M.' 'Molcan A.']...
#   Comment: 5 unique values -> ['Completed' 'Retired' 'Walkover' 'Awarded' 'Rrtired']
#
# --- 2022 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 65 unique values -> ['Adelaide' 'Melbourne' 'Sydney' 'Cordoba' 'Montpellier' 'Pune'
#  'Buenos Aires' 'Dallas' 'Rotterdam' 'Delray Beach']...
#   Tournament: 67 unique values -> ['Adelaide International 1' 'Melbourne Summer Set'
#  'Adelaide International 2' 'Sydney Tennis Classic' 'Australian Open'
#  'Cordoba Open' 'Open Sud de France' 'Maharashtra Open' 'Argentina Open'
#  'Dallas Open']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 209 unique values -> ['Kwon S.W.' 'Monteiro T.' 'Djere L.' 'Johnson S.' 'Moutet C.' 'Daniel T.'
#  'Gerasimov E.' 'Ymer M.' 'Cerundolo J.M.' 'Paul T.']...
#   Loser: 306 unique values -> ['Nishioka Y.' 'Altmaier D.' 'Carballes Baena R.' 'Vukic A.' 'Rune H.'
#  'Musetti L.' 'Fucsovics M.' 'Bonzi B.' 'Bolt A.' 'Vesely J.']...
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']
#
# --- 2023 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 63 unique values -> ['Adelaide' 'Pune' 'Auckland' 'Melbourne' 'Cordoba' 'Dallas' 'Montpellier'
#  'Buenos Aires' 'Delray Beach' 'Rotterdam']...
#   Tournament: 64 unique values -> ['Adelaide International 1' 'Maharashtra Open' 'Adelaide International 2'
#  'ASB Classic' 'Australian Open' 'Cordoba Open' 'Dallas Open'
#  'Open Sud de France' 'Argentina Open' 'Delray Beach Open']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 224 unique values -> ['Giron M.' 'Mcdonald M.' 'Kecmanovic M.' 'Nishioka Y.' 'Popyrin A.'
#  'Halys Q.' 'Safiullin R.' 'Draper J.' 'Kokkinakis T.' 'Medvedev D.']...
#   Loser: 319 unique values -> ['Gasquet R.' 'Galan D.E.' 'O Connell C.' 'Rune H.' 'Auger-Aliassime F.'
#  'Thompson J.' 'Ymer M.' 'Kwon S.W.' 'Cressy M.' 'Sonego L.']...
#   Comment: 4 unique values -> ['Completed' 'Retired' 'Walkover' 'Awarded']
#
# --- 2024 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 64 unique values -> ['Brisbane' 'Hong Kong' 'Adelaide' 'Auckland' 'Melbourne' 'Montpellier'
#  'Cordoba' 'Dallas' 'Marseille' 'Buenos Aires']...
#   Tournament: 64 unique values -> ['Brisbane International' 'Hong Kong Tennis Open' 'Adelaide International'
#  'ASB Classic' 'Australian Open' 'Open Sud de France' 'Cordoba Open'
#  'Dallas Open' 'Open 13' 'Argentina Open']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 211 unique values -> ['Popyrin A.' 'Shevchenko A.' 'Safiullin R.' 'Rune H.' 'Dimitrov G.'
#  'Hanfmann Y.' 'Klein L.' 'Duckworth J.' 'Altmaier D.' 'Machac T.']...
#   Loser: 291 unique values -> ['O Connell C.' 'Van Assche L.' 'Shelton B.' 'Purcell M.' 'Murray A.'
#  'Korda S.' 'Baez S.' 'Wolf J.J.' 'Tu L.' 'Etcheverry T.']...
#   Comment: 4 unique values -> ['Completed' 'Retired' 'Walkover' 'Awarded']
#
# --- 2025 ---
# Numerical columns: ['ATP', 'Best of', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets']
#
# Categorical columns: ['Location', 'Tournament', 'Series', 'Court', 'Surface', 'Round', 'Winner', 'Loser', 'Comment']
#   Location: 59 unique values -> ['Brisbane' 'Hong Kong' 'Adelaide' 'Auckland' 'Melbourne' 'Montpellier'
#  'Dallas' 'Rotterdam' 'Buenos Aires' 'Delray Beach']...
#   Tournament: 60 unique values -> ['Brisbane International' 'Hong Kong Tennis Open' 'Adelaide International'
#  'ASB Classic' 'Australian Open' 'Open Sud de France' 'Dallas Open'
#  'ABN AMRO World Tennis Tournament' 'Argentina Open' 'Delray Beach Open']...
#   Series: 5 unique values -> ['ATP250' 'Grand Slam' 'ATP500' 'Masters 1000' 'Masters Cup']
#   Court: 2 unique values -> ['Outdoor' 'Indoor']
#   Surface: 3 unique values -> ['Hard' 'Clay' 'Grass']
#   Round: 8 unique values -> ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin']
#   Winner: 213 unique values -> ['Vukic A.' 'Michelsen A.' 'Bonzi B.' 'Nishioka Y.' 'Thompson J.'
#  'Jarry N.' 'Dimitrov G.' 'Lehecka J.' 'Opelka R.' 'Arnaldi M.']...
#   Loser: 297 unique values -> ['Goffin D.' 'O Connell C.' 'Tabilo A.' 'Rinderknech A.' 'Berrettini M.'
#  'Navone M.' 'Hanfmann Y.' 'Rune H.' 'Gomez F.' 'Popyrin A.']...
#   Comment: 3 unique values -> ['Completed' 'Retired' 'Walkover']

# %% [markdown]
# ### 1.3.6 - Merge into 1 dataframe

# %%
full_df = pd.concat(dfs.values(), ignore_index=True)

# %%
full_df.isna().sum()
# Out:
# ATP               0
# Location          0
# Tournament        0
# Date              0
# Series            0
# Court             0
# Surface           0
# Round             0
# Best of          15
# Winner            0
# Loser             0
# WRank            18
# LRank           112
# WPts           1692
# LPts           1784
# W1              339
# L1              336
# W2              832
# L2              832
# W3            29027
# L3            29027
# W4            49629
# L4            49629
# W5            52857
# L5            52857
# Wsets           332
# Lsets           334
# Comment           0
# dtype: int64

# %%
# Additional checks and fill missing values
# 1. Ranks & Points
max_rank = full_df[['WRank', 'LRank']].max().max()
full_df['WRank'] = full_df['WRank'].fillna(max_rank + 1)
full_df['LRank'] = full_df['LRank'].fillna(max_rank + 1)
full_df['WPts'] = pd.to_numeric(full_df['WPts'], errors='coerce').fillna(0)
full_df['LPts'] = pd.to_numeric(full_df['LPts'], errors='coerce').fillna(0)

# 2. Set Scores & Format
full_df['Best of'] = full_df.apply(lambda r: 5 if r['Series'] == 'Grand Slam' else 3 if pd.isna(r['Best of']) else r['Best of'], axis=1)
full_df[['Wsets', 'Lsets']] = full_df[['Wsets', 'Lsets']].fillna(0)

# 3. Game columns (W1-L5)
# Filter out matches that weren't actually played (Walkovers, Retirements) to ensure game/set stats are valid for Block 1 (Fatigue) calculations later
full_df = full_df[full_df['Comment'] == 'Completed']
full_df = full_df[~((full_df['Comment'] == 'Completed') & (df['Wsets'].isna()))]
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_35084\4005708970.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   full_df = full_df[~((full_df['Comment'] == 'Completed') & (df['Wsets'].isna()))]

# %% [markdown]
# ### 1.3.7 - Dataset statistics

# %%
# Date range
print("Date range:", full_df["Date"].min(), "to", full_df["Date"].max())
# Out:
# Date range: 2005-01-03 00:00:00 to 2025-11-16 00:00:00

# %%
print(list(full_df.columns))
# Out:
# ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment']

# %%
# Ensure numeric
full_df["WRank"] = pd.to_numeric(full_df["WRank"], errors="coerce")
full_df["LRank"] = pd.to_numeric(full_df["LRank"], errors="coerce")
full_df["WPts"] = pd.to_numeric(full_df["WPts"], errors="coerce")
full_df["LPts"] = pd.to_numeric(full_df["LPts"], errors="coerce")

# Clean data
df_rank = full_df.dropna(subset=["WRank", "LRank"]).copy()
df_rank = df_rank[(df_rank["WRank"] <= 500) & (df_rank["LRank"] <= 500)]

df_points = full_df.dropna(subset=["WPts", "LPts"]).copy()
df_points = df_points[(df_points["WPts"] > 0) & (df_points["LPts"] > 0)]

# Create figure with 2 subplots
fig, axes = plt.subplots(1, 2, figsize=(14,6))

# Rank histogram
axes[0].hist([df_rank["WRank"], df_rank["LRank"]],
             bins=50,
             stacked=True,
             label=["Winner Rank", "Loser Rank"])
axes[0].set_title("Winner vs Loser Rank Distribution", fontsize=18)
axes[0].set_xlabel("ATP Rank", fontsize=14)
axes[0].set_ylabel("Match Count", fontsize=14)
axes[0].legend()
axes[0].grid(True)

# Points histogram
axes[1].hist([df_points["WPts"], df_points["LPts"]],
             bins=50,
             stacked=True,
             label=["Winner Points", "Loser Points"])
axes[1].set_yscale("log")
axes[1].set_title("Winner vs Loser Points Distribution", fontsize=18)
axes[1].set_xlabel("ATP Points", fontsize=14)
axes[1].set_ylabel("Match Count (Log Scale)", fontsize=14)
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.savefig("tennis_plot_histogram.png", dpi=300)
plt.show()

# %%
# Surface counts
surface_counts = full_df["Surface"].value_counts()
print(surface_counts)
plt.figure(figsize=(6,4))
surface_counts.plot(kind='bar', color='green')
plt.title("Surface Type Distribution")
plt.xlabel("Surface")
plt.ylabel("Count")
plt.show()
# Out:
# Surface
# Hard      29351
# Clay      16621
# Grass      5976
# Carpet      810
# Name: count, dtype: int64

# %%
# Court type
indoor_counts = full_df["Court"].value_counts()
indoor_counts.plot(kind='bar', color="red")
plt.title("Matches by Court Type")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()

# %%
# Unique player and tournaments
unique_players = set(full_df["Winner"]).union(set(full_df["Loser"]))
print("Unique players:", len(unique_players))
print("Unique tournaments:", full_df["Tournament"].nunique())
# Out:
# Unique players: 1484
# Unique tournaments: 218

# %%
# Best of counts
best_of_counts = full_df["Best of"].value_counts()
print(best_of_counts)
plt.figure(figsize=(6,4))
best_of_counts.plot(kind='bar', color='orange')
plt.title("Match Format (Best of)")
plt.xlabel("Best of")
plt.ylabel("Count")
plt.show()
# Out:
# Best of
# 3.0    42636
# 5.0    10122
# Name: count, dtype: int64

# %% [markdown]
# # 2 - Modeling

# %% [markdown]
# ## 2.1 - Additional filtering and cleaning

# %%
df = full_df.copy()

# Convert Date to datetime and sort to preserve chronological order
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date').reset_index(drop=True)


# --- OPTIMIZATION: ELO RATINGS ---
def calculate_elo(df, k_factor=32):
    elo_dict = {}
    winner_elos = []
    loser_elos = []
    
    for idx, row in df.iterrows():
        w = row['Winner']
        l = row['Loser']
        
        # Get current Elo or default to 1500 for new players
        w_elo = elo_dict.get(w, 1500)
        l_elo = elo_dict.get(l, 1500)
        
        winner_elos.append(w_elo)
        loser_elos.append(l_elo)
        
        # Calculate expected win probability based on current Elo
        expected_w = 1 / (1 + 10 ** ((l_elo - w_elo) / 400))
        expected_l = 1 / (1 + 10 ** ((w_elo - l_elo) / 400))
        
        # Update dictionary with new Elo after match result
        elo_dict[w] = w_elo + k_factor * (1 - expected_w)
        elo_dict[l] = l_elo + k_factor * (0 - expected_l)
        
    df['Winner_Elo'] = winner_elos
    df['Loser_Elo'] = loser_elos
    return df

# Apply Elo calculations sequentially across the entire history
df = calculate_elo(df)

# Convert ranks and points to numeric, coercing errors (like 'NR' for Not Ranked) to NaN
for col in ['WRank', 'LRank', 'WPts', 'LPts']:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %% [markdown]
# ## 2.2 - Data structuring

# %%
# Convert winner/loser to Player A / Player B
np.random.seed(42)
# Create a boolean mask to randomly swap Winner/Loser 50% of the time
swap = np.random.rand(len(df)) > 0.5

# Assign players
df['Player_A'] = np.where(swap, df['Loser'], df['Winner'])
df['Player_B'] = np.where(swap, df['Winner'], df['Loser'])

# Target variable: 1 if Player A wins, 0 if Player A loses
df['Target_A_Win'] = np.where(swap, 0, 1)

# Map Ranks and Points based on the swap
df['Rank_A'] = np.where(swap, df['LRank'], df['WRank'])
df['Rank_B'] = np.where(swap, df['WRank'], df['LRank'])
df['Pts_A'] = np.where(swap, df['LPts'], df['WPts'])
df['Pts_B'] = np.where(swap, df['WPts'], df['LPts'])

# %% [markdown]
# ## 2.3 - Block 0

# %% [markdown]
# ### 0.1 - Feature engineering

# %% [markdown]
# #### 0.1.1 - Rank and points

# %%
# Point and rank differences from the perspective of Player A
df['Rank_Diff_A_B'] = df['Rank_A'] - df['Rank_B']
df['Pts_Diff_A_B'] = df['Pts_A'] - df['Pts_B']

# %% [markdown]
# #### 0.1.2 - ELO

# %%
# --- ELO DIFFERENTIAL ---
def calculate_elo(df, k_factor=32):
    elo_dict = {}          # global ELO: {player: rating}
    surface_elo_dict = {}  # surface ELO: {player: {surface: rating}}

    winner_elos, loser_elos = [], []
    winner_surface_elos, loser_surface_elos = [], []

    for idx, row in df.iterrows():
        w, l, surface = row['Winner'], row['Loser'], row['Surface']

        # --- Global ELO (unchanged) ---
        w_elo = elo_dict.get(w, 1500)
        l_elo = elo_dict.get(l, 1500)

        winner_elos.append(w_elo)
        loser_elos.append(l_elo)

        exp_w = 1 / (1 + 10 ** ((l_elo - w_elo) / 400))
        exp_l = 1 / (1 + 10 ** ((w_elo - l_elo) / 400))

        elo_dict[w] = w_elo + k_factor * (1 - exp_w)
        elo_dict[l] = l_elo + k_factor * (0 - exp_l)

        # --- Surface-specific ELO (new) ---
        w_srf = surface_elo_dict.setdefault(w, {}).get(surface, 1500)
        l_srf = surface_elo_dict.setdefault(l, {}).get(surface, 1500)

        winner_surface_elos.append(w_srf)
        loser_surface_elos.append(l_srf)

        exp_w_srf = 1 / (1 + 10 ** ((l_srf - w_srf) / 400))
        exp_l_srf = 1 / (1 + 10 ** ((w_srf - l_srf) / 400))

        surface_elo_dict[w][surface] = w_srf + k_factor * (1 - exp_w_srf)
        surface_elo_dict[l][surface] = l_srf + k_factor * (0 - exp_l_srf)

    df['Winner_Elo']         = winner_elos
    df['Loser_Elo']          = loser_elos
    df['Winner_Surface_Elo'] = winner_surface_elos
    df['Loser_Surface_Elo']  = loser_surface_elos
    return df

df = calculate_elo(df)

# --- ELO MAPPING ---
df['Elo_A'] = np.where(swap, df['Loser_Elo'], df['Winner_Elo'])
df['Elo_B'] = np.where(swap, df['Winner_Elo'], df['Loser_Elo'])
# --- ELO DIFFERENTIAL ---
df['Elo_Diff_A_B'] = df['Elo_A'] - df['Elo_B']

# --- SURFACE ELO MAPPING ---
df['Surface_Elo_A'] = np.where(swap, df['Loser_Surface_Elo'], df['Winner_Surface_Elo'])
df['Surface_Elo_B'] = np.where(swap, df['Winner_Surface_Elo'], df['Loser_Surface_Elo'])
# --- SURFACE ELO DIFFERENTIAL ---
df['Surface_Elo_Diff_A_B'] = df['Surface_Elo_A'] - df['Surface_Elo_B']

# %% [markdown]
# #### 0.1.3 - H2H

# %%
h2h_dict = defaultdict(lambda: defaultdict(int))  # h2h_dict[winner][loser] = prior wins

h2h_wins_A_list = []
h2h_wins_B_list = []

for _, row in df.iterrows():
    pA, pB = row['Player_A'], row['Player_B']

    # Read PRIOR wins before this match (no leakage)
    wins_A = h2h_dict[pA][pB]
    wins_B = h2h_dict[pB][pA]

    h2h_wins_A_list.append(wins_A)
    h2h_wins_B_list.append(wins_B)

    # Update AFTER recording pre-match state
    if row['Target_A_Win'] == 1:
        h2h_dict[pA][pB] += 1
    else:
        h2h_dict[pB][pA] += 1

df['H2H_Wins_A'] = h2h_wins_A_list
df['H2H_Wins_B'] = h2h_wins_B_list
df['H2H_Total']  = df['H2H_Wins_A'] + df['H2H_Wins_B']

# Raw differential (main signal: positive means A has beaten B more often)
df['H2H_Wins_Diff'] = df['H2H_Wins_A'] - df['H2H_Wins_B']

# Bayesian-smoothed win rate (handles first meetings gracefully; alpha=3 = mild prior toward 0.5)
alpha = 3
df['H2H_Win_Rate_A'] = (df['H2H_Wins_A'] + alpha) / (df['H2H_Total'] + 2 * alpha)

# %% [markdown]
# ### 0.2 - Create final Block 0 differential features

# %%
# Create a clean dataframe for the baseline model
baseline_cols = ['Date', 'Tournament', 'Surface', 'Player_A', 'Player_B', 
                 'Rank_Diff_A_B', 'Pts_Diff_A_B', 'Elo_Diff_A_B',
                 'H2H_Wins_Diff', 'H2H_Win_Rate_A', 'H2H_Total',
                 'Target_A_Win', 'Surface_Elo_Diff_A_B']
model_df = df[baseline_cols].copy()

# %% [markdown]
# ### 0.3 - Dataset split

# %%
# 1. Training Set (2005 to 2019)
train_set = model_df[model_df['Date'].dt.year <= 2019].copy()

# 2. Validation Set (2020 to 2023)
val_set = model_df[(model_df['Date'].dt.year >= 2020) & (model_df['Date'].dt.year <= 2023)].copy()

# 3. Testing Set (2024 to 2025)
test_set = model_df[model_df['Date'].dt.year >= 2024].copy()

# Verify the splits
print(f"Total Matches: {len(model_df)}")
print(f"Training Set: {len(train_set)} matches ({len(train_set)/len(model_df):.1%})")
print(f"Validation Set: {len(val_set)} matches ({len(val_set)/len(model_df):.1%})")
print(f"Testing Set: {len(test_set)} matches ({len(test_set)/len(model_df):.1%})")
# Out:
# Total Matches: 52758
# Training Set: 38826 matches (73.6%)
# Validation Set: 8808 matches (16.7%)
# Testing Set: 5124 matches (9.7%)

# %% [markdown]
# ## 2.4 - Block 1

# %% [markdown]
# ### 1.1 - Calculate Total Games and Sets for each historical match

# %%
# Use original 'df' from before swapping A/B to calculate match stats
game_cols = ['W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5']
for col in game_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

# Sum across the row for total games
df['Total_Games'] = df[game_cols].sum(axis=1)

# Sum total sets
df['Total_Sets'] = pd.to_numeric(df['Wsets'], errors='coerce').fillna(0) + \
                   pd.to_numeric(df['Lsets'], errors='coerce').fillna(0)

# %% [markdown]
# ### 1.2 - Create player history dataframe

# %%
winners = df[['Date', 'Winner', 'Total_Sets', 'Total_Games']].rename(columns={'Winner': 'Player'})
losers = df[['Date', 'Loser', 'Total_Sets', 'Total_Games']].rename(columns={'Loser': 'Player'})

# Combine, sort chronologically, and drop duplicates if a player played twice in one day
player_history = pd.concat([winners, losers]).sort_values(by=['Player', 'Date']).drop_duplicates(subset=['Player', 'Date'])

# %% [markdown]
# ### 1.3 - Calculate rest days since last match

# %%
player_history['Days_Since_Last_Match'] = player_history.groupby('Player')['Date'].diff().dt.days

# %% [markdown]
# ### 1.4 - Calculate 14-day rolling load

# %%
# --- NEW CODE: EWMA FATIGUE (Replaces old rolling window) ---
# Sort chronologically by player
player_history = player_history.sort_values(by=['Player', 'Date'])

# Calculate Exponential Moving Average (span=14 matches)
# .shift(1) ensures the EWMA only includes matches prior to the current row
ewma_metrics = player_history.groupby('Player')[['Total_Sets', 'Total_Games']].apply(
    lambda x: x.shift(1).ewm(span=14, adjust=False).mean()
).reset_index(level=0, drop=True)

player_history['Total_Sets_EWMA'] = ewma_metrics['Total_Sets']
player_history['Total_Games_EWMA'] = ewma_metrics['Total_Games']

# Fill NA for a player's very first match
player_history.fillna({'Total_Sets_EWMA': 0, 'Total_Games_EWMA': 0}, inplace=True)

# Create the final metrics dataframe
fatigue_metrics = player_history[['Date', 'Player', 'Days_Since_Last_Match', 'Total_Sets_EWMA', 'Total_Games_EWMA']].copy()

# %% [markdown]
# ### 1.5 - Merge Block 1 features into model_df

# %%
# Merge for Player A
model_df = pd.merge(model_df, fatigue_metrics.add_suffix('_A'), 
                    left_on=['Date', 'Player_A'], right_on=['Date_A', 'Player_A'], how='left').drop(columns=['Date_A'])

# Merge for Player B
model_df = pd.merge(model_df, fatigue_metrics.add_suffix('_B'), 
                    left_on=['Date', 'Player_B'], right_on=['Date_B', 'Player_B'], how='left').drop(columns=['Date_B'])

# %% [markdown]
# ### 1.6 - Create final Block 1 differential features

# %%
# --- NEW CODE: EWMA DIFFERENTIALS ---
model_df['Sets_Played_EWMA_Diff'] = model_df['Total_Sets_EWMA_A'] - model_df['Total_Sets_EWMA_B']
model_df['Games_Played_EWMA_Diff'] = model_df['Total_Games_EWMA_A'] - model_df['Total_Games_EWMA_B']
model_df['Rest_Days_Diff'] = model_df['Days_Since_Last_Match_A'] - model_df['Days_Since_Last_Match_B']

# %% [markdown]
# ## 2.5 - Block 2

# %% [markdown]
# ### 2.1 - Create a long DataFrame for Surface Performance

# %%
winners_sfc = df[['Date', 'Winner', 'Surface']].copy()
winners_sfc['Player'] = winners_sfc['Winner']
winners_sfc['Won'] = 1
winners_sfc = winners_sfc.drop(columns=['Winner'])

losers_sfc = df[['Date', 'Loser', 'Surface']].copy()
losers_sfc['Player'] = losers_sfc['Loser']
losers_sfc['Won'] = 0
losers_sfc = losers_sfc.drop(columns=['Loser'])

# Combine and sort chronologically
surface_history = pd.concat([winners_sfc, losers_sfc]).sort_values(by=['Player', 'Surface', 'Date'])

# %% [markdown]
# ### 2.2 - Calculate historical wins and matches (excluding current match)

# %%
grouped = surface_history.groupby(['Player', 'Surface'])

# cumcount() starts at 0, which perfectly represents the number of matches played BEFORE the current one
surface_history['Historical_Matches_On_Surface'] = grouped.cumcount()

# Cumulative sum of wins minus the current match's result gives previous wins
surface_history['Historical_Wins_On_Surface'] = grouped['Won'].cumsum() - surface_history['Won']

# %% [markdown]
# ### 2.3 - Calculate win rate on surface

# %%
# If a player has never played on this surface before, default their win rate to 0
surface_history['Surface_Win_Rate'] = np.where(
    surface_history['Historical_Matches_On_Surface'] > 0, 
    surface_history['Historical_Wins_On_Surface'] / surface_history['Historical_Matches_On_Surface'], 
    0 
)

# %% [markdown]
# ### 2.4 - Clean up for merging

# %%
surface_features = surface_history[['Date', 'Player', 'Surface', 'Surface_Win_Rate', 'Historical_Matches_On_Surface']]
# Drop duplicates in the rare case a player plays two matches on the same surface in one day
surface_features = surface_features.drop_duplicates(subset=['Date', 'Player', 'Surface'])

# %% [markdown]
# ### 2.5 - Merge block 2 features to model_df

# %%
# Merge for Player A
model_df = pd.merge(model_df, 
                    surface_features.rename(columns={'Player': 'Player_A', 
                                                     'Surface_Win_Rate': 'Surface_Win_Rate_A',
                                                     'Historical_Matches_On_Surface': 'Matches_On_Surface_A'}), 
                    on=['Date', 'Player_A', 'Surface'], 
                    how='left')

# Merge for Player B
model_df = pd.merge(model_df, 
                    surface_features.rename(columns={'Player': 'Player_B', 
                                                     'Surface_Win_Rate': 'Surface_Win_Rate_B',
                                                     'Historical_Matches_On_Surface': 'Matches_On_Surface_B'}), 
                    on=['Date', 'Player_B', 'Surface'], 
                    how='left')

# Fill any lingering NaNs (e.g., players completely missing from the history merge) with 0
model_df.fillna({'Surface_Win_Rate_A': 0, 'Surface_Win_Rate_B': 0}, inplace=True)

# %% [markdown]
# ### 2.6 - Create final Block 2 differential features

# %%
model_df['Surface_Win_Rate_Diff'] = model_df['Surface_Win_Rate_A'] - model_df['Surface_Win_Rate_B']

# %% [markdown]
# # 3 - Model training and validation evaluation

# %% [markdown]
# ## 3.1 - Feature blocks

# %%
# Define Feature Blocks based on engineered columns
block_0 = ['Rank_Diff_A_B', 'Pts_Diff_A_B', 'Elo_Diff_A_B', 'H2H_Wins_Diff', 'H2H_Win_Rate_A', 'H2H_Total']
block_1 = ['Sets_Played_EWMA_Diff', 'Games_Played_EWMA_Diff', 'Rest_Days_Diff']
block_2 = ['Surface_Win_Rate_Diff', 'Surface_Elo_Diff_A_B']

# Define the incremental model configurations
feature_sets = {
    '1. Baseline (Block 0)': block_0,
    '2. Baseline + Fatigue (Block 0, 1)': block_0 + block_1,
    '3. Baseline + Surface (Block 0, 2)': block_0 + block_2,
    '4. All Features (Block 0, 1, 2)': block_0 + block_1 + block_2
}

# %% [markdown]
# ## 3.2 - Data prep for modeling

# %%
# --- THE FIX: Re-split the dataset now that model_df has all new columns ---
train_set = model_df[model_df['Date'].dt.year <= 2019].copy()
val_set = model_df[(model_df['Date'].dt.year >= 2020) & (model_df['Date'].dt.year <= 2023)].copy()
test_set = model_df[model_df['Date'].dt.year >= 2024].copy()

# Extract all features used
all_features = list(set(block_0 + block_1 + block_2))

# Clean and prepare training/validation sets
train_clean = train_set.dropna(subset=all_features + ['Target_A_Win']).copy()
val_clean = val_set.dropna(subset=all_features + ['Target_A_Win']).copy()

y_train = train_clean['Target_A_Win']
y_val = val_clean['Target_A_Win']

print(f"Training on {len(train_clean)} matches, Validating on {len(val_clean)} matches.\n")
# Out:
# Training on 37747 matches, Validating on 8620 matches.

# %% [markdown]
# ## 3.3 - Train and evaluate incremental models

# %%
results = []
C_values = [0.01, 0.1, 1.0, 10.0]

for name, features in feature_sets.items():
    X_train = train_clean[features]
    X_val = val_clean[features]

    best_loss_LR = float('inf')
    best_auc_LR = 0
    best_c = 1.0

    # Grid search over C on the validation set
    for C in C_values:
        model = make_pipeline(StandardScaler(), LogisticRegression(C=C, random_state=42, max_iter=1000))
        model.fit(X_train, y_train)
        y_pred_proba = model.predict_proba(X_val)[:, 1]
        loss = log_loss(y_val, y_pred_proba)
        auc = roc_auc_score(y_val, y_pred_proba)

        if loss < best_loss_LR:
            best_loss_LR = loss
            best_auc_LR = auc
            best_c = C

    results.append({
        'Model configuration': name,
        'Log-Loss': round(best_loss_LR, 4),
        'AUC': round(best_auc_LR, 4),
        'Best C': best_c
    })
    print(f"{name} | Best C={best_c} | Log-Loss={best_loss_LR:.4f} | AUC={best_auc_LR:.4f}")
# Out:
# 1. Baseline (Block 0) | Best C=0.01 | Log-Loss=0.6205 | AUC=0.7094
# 2. Baseline + Fatigue (Block 0, 1) | Best C=0.01 | Log-Loss=0.6201 | AUC=0.7097
# 3. Baseline + Surface (Block 0, 2) | Best C=0.01 | Log-Loss=0.6187 | AUC=0.7116
# 4. All Features (Block 0, 1, 2) | Best C=0.01 | Log-Loss=0.6182 | AUC=0.7119

# %% [markdown]
# ## 3.4 -  Results

# %%
results_df = pd.DataFrame(results).set_index('Model configuration')

# Sort by Log-Loss to clearly see the best performing model
print("--- Validation Set Evaluation Results ---")
print(results_df.sort_values('Log-Loss'))
# Out:
# --- Validation Set Evaluation Results ---
#                                     Log-Loss     AUC  Best C
# Model configuration
# 4. All Features (Block 0, 1, 2)       0.6182  0.7119    0.01
# 3. Baseline + Surface (Block 0, 2)    0.6187  0.7116    0.01
# 2. Baseline + Fatigue (Block 0, 1)    0.6201  0.7097    0.01
# 1. Baseline (Block 0)                 0.6205  0.7094    0.01

# %% [markdown]
# ## 3.5 - Alternative algorithm comparison 1 - Random Forest

# %%
# 1. Isolate the winning feature set
best_features = block_0 + block_1 + block_2

X_train_best = train_clean[best_features]
X_val_best = val_clean[best_features]

# 2. Initialize the Random Forest model
# Note: Tree-based models don't require StandardScaler, so we can fit directly
# We constrain max_depth to prevent overfitting on the training data
rf_model = RandomForestClassifier(n_estimators=200, max_depth=10, random_state=42, n_jobs=-1)

# 3. Train the new model
print("Training Random Forest...")
rf_model.fit(X_train_best, y_train)

# 4. Predict probabilities on the validation set
rf_pred_proba = rf_model.predict_proba(X_val_best)[:, 1]

# 5. Evaluate and Compare
rf_auc = roc_auc_score(y_val, rf_pred_proba)
rf_loss = log_loss(y_val, rf_pred_proba)

print(f"Random Forest Model:      Log-Loss = {rf_loss:.4f} | AUC = {rf_auc:.4f}")

# Optional: View Feature Importances to see what the Random Forest prioritized
importances = pd.Series(rf_model.feature_importances_, index=best_features).sort_values(ascending=False)
print("\n--- Random Forest Feature Importances ---")
print(importances)
# Out:
# Training Random Forest...
# Random Forest Model:      Log-Loss = 0.6198 | AUC = 0.7107
#
# --- Random Forest Feature Importances ---
# Elo_Diff_A_B              0.293400
# Surface_Elo_Diff_A_B      0.211151
# Pts_Diff_A_B              0.120795
# Surface_Win_Rate_Diff     0.112200
# Rank_Diff_A_B             0.109575
# Rest_Days_Diff            0.037873
# Games_Played_EWMA_Diff    0.037156
# Sets_Played_EWMA_Diff     0.036423
# H2H_Win_Rate_A            0.018884
# H2H_Wins_Diff             0.012221
# H2H_Total                 0.010322
# dtype: float64

# %% [markdown]
# ## 3.6 - Alternative algorithm comparison 2 - XGBoost

# %%
# hyperparameter tuning
xgb_param_grid = {
    'max_depth': [3, 4, 5],
    'learning_rate': [0.01, 0.05],
    'n_estimators': [300, 500],
    'subsample': [0.8],
    'colsample_bytree': [0.8]
}

best_xgb_loss = float('inf')
best_xgb_auc = 0
best_xgb_params = {}

print("Tuning XGBoost...")
for params in ParameterGrid(xgb_param_grid):
    xgb = XGBClassifier(**params, random_state=42, eval_metric='logloss', use_label_encoder=False, n_jobs=-1)
    xgb.fit(X_train_best, y_train)
    preds = xgb.predict_proba(X_val_best)[:, 1]
    loss = log_loss(y_val, preds)
    auc = roc_auc_score(y_val, preds)

    if loss < best_xgb_loss:
        best_xgb_loss = loss
        best_xgb_auc = auc
        best_xgb_params = params

print(f"\nBest XGBoost Params: {best_xgb_params}")
print(f"XGBoost Best:         Log-Loss = {best_xgb_loss:.4f} | AUC = {best_xgb_auc:.4f}")

# --- XGBoost Feature Importances ---
best_xgb_model = XGBClassifier(**best_xgb_params, random_state=42, eval_metric='logloss', use_label_encoder=False)
best_xgb_model.fit(X_train_best, y_train)
xgb_importances = pd.Series(best_xgb_model.feature_importances_, index=best_features).sort_values(ascending=False)
print("\n--- XGBoost Feature Importances ---")
print(xgb_importances)
# Out:
# Tuning XGBoost...
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:26] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:26] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best XGBoost Params: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 500, 'subsample': 0.8}
# XGBoost Best:         Log-Loss = 0.6182 | AUC = 0.7120
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:32] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# --- XGBoost Feature Importances ---
# Elo_Diff_A_B              0.497572
# Surface_Elo_Diff_A_B      0.204884
# Rank_Diff_A_B             0.076029
# Pts_Diff_A_B              0.059501
# Surface_Win_Rate_Diff     0.047466
# Rest_Days_Diff            0.028311
# Games_Played_EWMA_Diff    0.019317
# H2H_Win_Rate_A            0.018057
# H2H_Total                 0.017156
# Sets_Played_EWMA_Diff     0.017010
# H2H_Wins_Diff             0.014696
# dtype: float32

# %% [markdown]
# ## 3.7 - Alternative algorithm comparison 3 - LightGBM

# %%
# hyperparameter tuning
lgbm_param_grid = {
    'num_leaves': [15, 31, 50],
    'learning_rate': [0.01, 0.05],
    'n_estimators': [300, 500],
    'subsample': [0.8],
    'colsample_bytree': [0.8]
}

best_lgbm_loss = float('inf')
best_lgbm_auc = 0
best_lgbm_params = {}

print("Tuning LightGBM...")
for params in ParameterGrid(lgbm_param_grid):
    # verbose=-1 suppresses the excessive LightGBM warning outputs
    lgbm = LGBMClassifier(**params, random_state=42, verbose=-1, n_jobs=-1)
    lgbm.fit(X_train_best, y_train)
    preds = lgbm.predict_proba(X_val_best)[:, 1]
    loss = log_loss(y_val, preds)
    auc = roc_auc_score(y_val, preds)

    if loss < best_lgbm_loss:
        best_lgbm_loss = loss
        best_lgbm_auc = auc
        best_lgbm_params = params

print(f"Best LightGBM Params: {best_lgbm_params}")

# --- Feature Importances ---
best_lgbm_model = LGBMClassifier(**best_lgbm_params, random_state=42, verbose=-1)
best_lgbm_model.fit(X_train_best, y_train)
importances = pd.Series(best_lgbm_model.feature_importances_, index=best_features).sort_values(ascending=False)

# Normalize importances so they sum to 1.0 (to match XGBoost's default output style for easier reading)
importances = importances / importances.sum()

print(f"\n--- {best_lgbm_model.__class__.__name__} Feature Importances ---")
print(importances)
# Out:
# Tuning LightGBM...
# Best LightGBM Params: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'n_estimators': 500, 'num_leaves': 15, 'subsample': 0.8}
# C:\Users\brand\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\brand\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "C:\Users\brand\anaconda3\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\brand\anaconda3\Lib\subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\brand\anaconda3\Lib\subprocess.py", line 1554, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                              # no special security
#                              ^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#                              cwd,
#                              ^^^^
#                              startupinfo)
#                              ^^^^^^^^^^^^
# --- LGBMClassifier Feature Importances ---
# Elo_Diff_A_B              0.165714
# Rank_Diff_A_B             0.158000
# Surface_Win_Rate_Diff     0.139000
# Surface_Elo_Diff_A_B      0.133429
# Rest_Days_Diff            0.114571
# Pts_Diff_A_B              0.111429
# Games_Played_EWMA_Diff    0.072714
# Sets_Played_EWMA_Diff     0.066429
# H2H_Win_Rate_A            0.021571
# H2H_Total                 0.008857
# H2H_Wins_Diff             0.008286
# dtype: float64

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# 1. Re-train the optimal Logistic Regression model explicitly
# Using C=0.01 on the 'best_features' (All 3 blocks) as found in your tuning phase
best_lr_model = make_pipeline(
    StandardScaler(), 
    LogisticRegression(C=0.01, random_state=42, max_iter=1000)
)
best_lr_model.fit(X_train_best, y_train)

# 2. Update the dictionary with the correct variables
models_dict = {
    'Logistic Regression': best_lr_model,      
    'Random Forest': rf_model,             
    'XGBoost': best_xgb_model,                 
    'LightGBM': best_lgbm_model                 
}

plt.figure(figsize=(10, 8))

# 3. Loop through each model to calculate and plot its ROC curve
for name, m in models_dict.items():
    # Predict probabilities on the validation set
    # CRITICAL FIX: Use X_val_best so it has all 3 blocks of features
    y_pred_proba = m.predict_proba(X_val_best)[:, 1] 
    
    # Calculate False Positive Rate (fpr) and True Positive Rate (tpr)
    fpr, tpr, thresholds = roc_curve(y_val, y_pred_proba)
    roc_auc = auc(fpr, tpr)
    
    # Plot the curve
    plt.plot(fpr, tpr, lw=2, label=f'{name} (AUC = {roc_auc:.4f})')

# Plot the 50/50 random guess baseline
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--', label='Random Guess')

# Formatting
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (1 - Specificity)', fontsize=14)
plt.ylabel('True Positive Rate (Sensitivity)', fontsize=14)
plt.title('ROC Curve Comparison - All Models', fontsize=18, fontweight='bold')
plt.legend(loc="lower right", fontsize=13)
plt.grid(alpha=0.3)
plt.savefig("ROC_curve.png", dpi=300, bbox_inches='tight')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4 - Final evaluation on test set

# %% [markdown]
# ## 4.1 - Combine train and validation set

# %%
train_val_combined = pd.concat([train_clean, val_clean], axis=0)

X_train_final = train_val_combined[best_features]
y_train_final = train_val_combined['Target_A_Win']

# Drop NaNs in the Test Set to ensure clean evaluation
test_clean = test_set.dropna(subset=best_features + ['Target_A_Win']).copy()
X_test = test_clean[best_features]
y_test = test_clean['Target_A_Win']

# %% [markdown]
# ## 4.2 - Retrain using best algorithm and predict

# %%
# --- Summary ---
print("--- Algorithm Comparison (Validation Set) ---")
print(f"Logistic Regression: Log-Loss = {best_loss_LR:.4f} | AUC = {best_auc_LR:.4f}")
print(f"Random Forest:       Log-Loss = {rf_loss:.4f} | AUC = {rf_auc:.4f}")
print(f"XGBoost:             Log-Loss = {best_xgb_loss:.4f} | AUC = {best_xgb_auc:.4f}")
print(f"LightGBM:            Log-Loss = {best_lgbm_loss:.4f} | AUC = {best_lgbm_auc:.4f}")

best_algorithm = ""

if best_loss_LR < rf_loss and best_loss_LR < best_xgb_loss and best_loss_LR < best_lgbm_loss: # use logistic regression
    best_algorithm = "Logistic Regression"
    print("\n[Using Logistic Regression as final model]")
    final_model = make_pipeline(StandardScaler(), LogisticRegression(C=best_c, random_state=42, max_iter=1000))
    final_model.fit(X_train_final, y_train_final)
elif rf_loss < best_loss_LR and rf_loss < best_xgb_loss and rf_loss < best_lgbm_loss: # use random forest
    best_algorithm = "Random Forest"
    print("\n[Using Random Forest as final model]")
    final_model = RandomForestClassifier(n_estimators=200, max_depth=10, random_state=42, n_jobs=-1)
    final_model.fit(X_train_final, y_train_final)
elif best_xgb_loss < best_loss_LR and best_xgb_loss < rf_loss and best_xgb_loss < best_lgbm_loss: # use XGBoost
    best_algorithm = "XGBoost"
    print("\n[Using XGBoost as final model]")
    final_model = XGBClassifier(**best_xgb_params, random_state=42, eval_metric='logloss', use_label_encoder=False)
    final_model.fit(X_train_final, y_train_final)
elif best_lgbm_loss < best_loss_LR and best_lgbm_loss < rf_loss and best_lgbm_loss < best_xgb_loss: # use lightGBM
    best_algorithm = "LightGBM"
    print("\n[Using LightGBM as final model]")
    final_model = LGBMClassifier(**best_lgbm_params, random_state=42, verbose=-1)
    final_model.fit(X_train_final, y_train_final)

print(f"\nTraining Final Model on {len(X_train_final)} historical matches (2005-2023)...")
print(f"Evaluating on {len(X_test)} recent matches (2024-2025)...\n")

# Predict
y_test_pred_proba = final_model.predict_proba(X_test)[:, 1]
y_test_pred = final_model.predict(X_test)
# Out:
# --- Algorithm Comparison (Validation Set) ---
# Logistic Regression: Log-Loss = 0.6182 | AUC = 0.7119
# Random Forest:       Log-Loss = 0.6198 | AUC = 0.7107
# XGBoost:             Log-Loss = 0.6182 | AUC = 0.7120
# LightGBM:            Log-Loss = 0.6186 | AUC = 0.7116
#
# [Using XGBoost as final model]
# C:\Users\brand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [16:06:43] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training Final Model on 46367 historical matches (2005-2023)...
# Evaluating on 5029 recent matches (2024-2025)...

# %% [markdown]
# ## 4.3 - Calculate final metrics and report

# %%
test_auc = roc_auc_score(y_test, y_test_pred_proba)
test_loss = log_loss(y_test, y_test_pred_proba)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"=== FINAL TEST SET PERFORMANCE (2024-2025) - {best_algorithm} ===")
print(f"Log-Loss: {test_loss:.4f}")
print(f"AUC:      {test_auc:.4f}")
print(f"Accuracy: {test_accuracy:.2%}\n")

print("Classification Report:")
print(classification_report(y_test, y_test_pred, target_names=['Player A Loses', 'Player A Wins']))
# Out:
# === FINAL TEST SET PERFORMANCE (2024-2025) - XGBoost ===
# Log-Loss: 0.6160
# AUC:      0.7150
# Accuracy: 64.86%
#
# Classification Report:
#                 precision    recall  f1-score   support
#
# Player A Loses       0.65      0.65      0.65      2533
#  Player A Wins       0.64      0.65      0.65      2496
#
#       accuracy                           0.65      5029
#      macro avg       0.65      0.65      0.65      5029
#   weighted avg       0.65      0.65      0.65      5029

# %%
cm = confusion_matrix(y_test, y_test_pred)

print("Confusion Matrix:")
print(cm)

cm_df = pd.DataFrame(
    cm,
    index=["Actual: Loss", "Actual: Win"],
    columns=["Pred: Loss", "Pred: Win"]
)

print(cm_df)
# Out:
# Confusion Matrix:
# [[1638  895]
#  [ 872 1624]]
#               Pred: Loss  Pred: Win
# Actual: Loss        1638        895
# Actual: Win          872       1624

# %% [markdown]
# # 5 - Predicting match outcome

# %%
def predict_match(player_A, player_B, surface, match_date, raw_df, model, best_features):
    match_date = pd.to_datetime(match_date)
    
    # Filter historical data to matches strictly BEFORE the prediction date
    history = raw_df[(pd.to_datetime(raw_df['Date']) < match_date) & 
                     (raw_df['Comment'] == 'Completed')].copy()

    def get_player_stats(player):
        # Filter for matches involving this player
        p_history = history[(history['Winner'] == player) | (history['Loser'] == player)].sort_values('Date')
        
        if p_history.empty:
            raise ValueError(f"No historical data found for {player}")
            
        last_match = p_history.iloc[-1]
        is_winner = last_match['Winner'] == player
        
        # 1. Rank & Points
        rank = last_match['WRank'] if is_winner else last_match['LRank']
        pts = last_match['WPts'] if is_winner else last_match['LPts']
        
        # 2. Elo (The model expects 'Winner_Elo' / 'Loser_Elo' columns from your calc_elo step)
        elo = last_match['Winner_Elo'] if is_winner else last_match['Loser_Elo']
        
        # 3. EWMA Fatigue (Fetching the values calculated in Block 1)
        # Note: If these aren't in your 'df', ensure you've merged your 'fatigue_metrics' back into 'df'
        sets_ewma = last_match.get('Total_Sets_EWMA', 0)
        games_ewma = last_match.get('Total_Games_EWMA', 0)
        
        # 4. Surface Win Rate
        s_history = p_history[p_history['Surface'] == surface]
        s_win_rate = len(s_history[s_history['Winner'] == player]) / len(s_history) if not s_history.empty else 0.5
        
        # 5. Surface Elo (If your model uses it)
        s_elo = last_match.get('Surface_Elo_A', 1500) if is_winner else last_match.get('Surface_Elo_B', 1500)

        return float(rank), float(pts), float(elo), float(sets_ewma), float(games_ewma), float(s_win_rate), float(s_elo)

    def get_h2h_stats(pA, pB):
        # Look for past matches between these two specifically
        h2h = history[((history['Winner'] == pA) & (history['Loser'] == pB)) | 
                      ((history['Winner'] == pB) & (history['Loser'] == pA))]
        
        if h2h.empty:
            return 0, 0, 0.5 # Default for new matchups
        
        wins_A = len(h2h[h2h['Winner'] == pA])
        total = len(h2h)
        return wins_A - (total - wins_A), total, wins_A / total

    # Extract Stats
    rA, ptA, eloA, sewmaA, gewmaA, swrA, seloA = get_player_stats(player_A)
    rB, ptB, eloB, sewmaB, gewmaB, swrB, seloB = get_player_stats(player_B)
    
    h2h_diff, h2h_total, h2h_rate = get_h2h_stats(player_A, player_B)

    # Construct feature dictionary to match your 'best_features' exactly
    features = {
        'Rank_Diff_A_B': rA - rB,
        'Pts_Diff_A_B': ptA - ptB,
        'Elo_Diff_A_B': eloA - eloB,
        'Sets_Played_EWMA_Diff': sewmaA - sewmaB,
        'Games_Played_EWMA_Diff': gewmaA - gewmaB,
        'Surface_Win_Rate_Diff': swrA - swrB,
        'Surface_Elo_Diff_A_B': seloA - seloB,
        'H2H_Wins_Diff': h2h_diff,
        'H2H_Total': h2h_total,
        'H2H_Win_Rate_A': h2h_rate,
        'Rest_Days_Diff': 0 # Optional: add rest days logic if required
    }

    # Create the inference row
    X_inference = pd.DataFrame([features])
    
    # Ensure all required columns are present (fill missing with 0 if necessary)
    for col in best_features:
        if col not in X_inference.columns:
            X_inference[col] = 0
            
    X_inference = X_inference[best_features]

    # Predict
    prob = model.predict_proba(X_inference)[0][1]
    
    print(f"--- PREDICTION: {player_A} vs {player_B} ---")
    print(f"Elo Diff: {eloA - eloB:+.1f} | Surface WR Diff: {swrA - swrB:+.1%}")
    print(f"Win Probability {player_A}: {prob:.1%}")
    print("-" * 40)

# Call with your best_features list
predict_match("Tien L.", "Medvedev D.", "Hard", "2026-04-15", df, best_xgb_model, best_features)
# Out:
# --- PREDICTION: Tien L. vs Medvedev D. ---
# Elo Diff: -120.0 | Surface WR Diff: -12.9%
# Win Probability Tien L.: 32.2%
# ----------------------------------------

# %% [markdown]
# # 6 - Sensitivity analysis

# %%
import matplotlib.pyplot as plt
from sklearn.inspection import PartialDependenceDisplay

plt.rcParams.update({
    'font.size': 14,          # base font size
    'axes.titlesize': 16,
    'axes.labelsize': 16,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14
})

# Choose the top features you want to analyze
# Replace these with the exact column names from your 'best_features' list
features_to_analyze = ['Elo_Diff_A_B', 'Rank_Diff_A_B', 'Surface_Elo_Diff_A_B', 'Pts_Diff_A_B']

fig, ax = plt.subplots(2, 2, figsize=(12, 10))

# Plot Partial Dependence (Global Sensitivity)
# We use X_train_final to see how the model learned the feature landscapes
display = PartialDependenceDisplay.from_estimator(
    estimator=best_xgb_model,           # Replace with your trained XGBoost variable
    X=X_train_final, 
    features=features_to_analyze,
    feature_names=best_features,   # Ensures the axes are labeled correctly
    kind="both",                   # 'both' plots the average (PDP) and individual lines (ICE)
    subsample=100,                 # Sample 100 lines for visual clarity
    n_jobs=-1,
    ax=ax,
    line_kw={"color": "red", "linewidth": 2},       # PDP line style
    ice_lines_kw={"color": "blue", "alpha": 0.05}   # ICE lines style
)

plt.suptitle("Global Sensitivity Analysis (PDP & ICE)\nHow Features Affect Player A's Win Probability", 
             fontsize=18, fontweight='bold')
plt.subplots_adjust(top=0.85)
plt.savefig("sensitivity_analysis_plots.png", dpi=300, bbox_inches='tight')
plt.show()
